# %%
# Load Data
import pandas as pd
import ray

ray.shutdown()
ray.init(object_store_memory=4000000000) # set object store memory to 4GB

data = pd.read_pickle('C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\data\\pickle_files\\full_dataset.pkl')
sample = data.sample(10001, random_state=26)

# tansform 'Rating' from Categorical to float
import numpy as np
sample["Rating"] = pd.to_numeric(sample["Rating"], errors='coerce')

# drop all rows with inf/-inf values!
import numpy as np
sample = sample[(sample != np.inf).all(axis=1)]
sample = sample[(sample != -np.inf).all(axis=1)]

#get rid of whitespace to draw tree later
Eq_Stylebox = sample['Eq_Stylebox_Long'].astype('object').replace(' ','_', regex=True)
sample['Eq_Stylebox_Long'] = Eq_Stylebox.astype('category')

# shifting target variable to predict next month
sample['returns'] = sample.returns.shift(-1)
sample = sample.drop(sample.tail(1).index)


X = sample.drop('returns', axis=1)
y = sample['returns']

# create dummies in case of categorical data
dummy_needed = [#'Rating',
                'Financial_Health_Grade_Long',
                 'Growth_Grade_Long',
                 'Profitability_Grade_Long',
                 'Eq_Stylebox_Long']

X = pd.get_dummies(X, columns=dummy_needed)

# Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 26)
X_train = ray.put(X_train)
y_train = ray.put(y_train)
# Out:
# 2023-04-13 09:13:55,797	INFO worker.py:1553 -- Started a local Ray instance.

# %%
# %%time
import xgboost as xgb
from hyperopt import hp, fmin, tpe, Trials
from ray import tune
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.search.hyperopt import HyperOptSearch
from sklearn.model_selection import cross_val_score, KFold
import numpy as np


# Define the search space for hyperparameters
search_space = {
    "learning_rate": hp.loguniform("learning_rate", np.log(0.0001), np.log(0.9)),
    "max_depth": hp.choice("max_depth", range(1, 16)),
    "n_estimators": hp.choice("n_estimators", range(100, 10000)),
    "subsample": hp.uniform("subsample", 0.5, 1),
    "colsample_bytree": hp.uniform("colsample_bytree", 0.5, 1),
    "colsample_bylevel": hp.uniform("colsample_bylevel", 0.5, 1),
    "reg_alpha": hp.loguniform("reg_alpha", np.log(0.001), np.log(100)),
    "reg_lambda": hp.loguniform("reg_lambda", np.log(0.001), np.log(100)),
}


kfolds = KFold(n_splits=5, shuffle=True, random_state=26)

# Define the objective function to optimize
def objective(config):
    model = xgb.XGBRegressor(**config, n_jobs=-1)
    score = cross_val_score(model, X=ray.get(X_train), y=ray.get(y_train), scoring="neg_mean_squared_error", cv=kfolds)
    rmse = np.sqrt(-np.mean(score))
    tune.report(rmse=rmse)

# Define the search algorithm
search_alg = HyperOptSearch(space=search_space, metric="rmse", mode="min")
# to limit number of cores, uncomment and set max_concurrent 
# algo = ConcurrencyLimiter(algo, max_concurrent=10)
scheduler = AsyncHyperBandScheduler()

# Define the hyperparameter tuning trials object
trials = Trials()

# Define the configuration for Ray Tune
config = {
    'num_samples': 10,
    'config': search_space,
    'search_alg': search_alg,
    'scheduler': scheduler,
    'resources_per_trial': {'cpu': 1},
    'metric': 'rmse',
    'mode': 'min',
    'verbose': 1,
    'name': 'xgboost_tuning',
    'stop': {'training_iteration': 10},
    'local_dir': './ray_results',
}

# Start the hyperparameter tuning using Ray Tune
analysis = tune.run(objective, **config)

# Print the best hyperparameters found during the search
best_params = analysis.get_best_config(metric='rmse')
print("Best hyperparameters found:")
print(best_params)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023
ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\search_gen_state-2023-04-13_09-14-14.json'
# 2023-04-13 11:46:37,027	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 11:47:47,595	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 11:47:54,029	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 11:48:32,405	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 12:20:39,965	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_search_generator_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\search_gen_state-2023-04-13_09-14-14.json'
# 2023-04-13 12:22:48,505	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 12:22:54,838	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 12:23:01,065	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 13:20:38,809	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 13:21:05,590	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 13:21:21,675	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 13:22:04,171	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 13:22:30,908	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 13:33:49,684	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_search_generator_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\search_gen_state-2023-04-13_09-14-14.json'
# 2023-04-13 13:33:54,773	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_checkpoint' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\experiment_state-2023-04-13_09-14-14.json'
# 2023-04-13 13:59:22,755	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 14:11:39,635	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_search_generator_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\search_gen_state-2023-04-13_09-14-14.json'
# 2023-04-13 14:11:44,705	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_checkpoint' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\experiment_state-2023-04-13_09-14-14.json'
# 2023-04-13 14:43:49,966	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_search_generator_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\search_gen_state-2023-04-13_09-14-14.json'
# 2023-04-13 14:43:55,064	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_checkpoint' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\experiment_state-2023-04-13_09-14-14.json'
# 2023-04-13 15:08:07,493	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_checkpoint' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\experiment_state-2023-04-13_09-14-14.json'
# 2023-04-13 15:08:12,557	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_checkpoint' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\experiment_state-2023-04-13_09-14-14.json'
# 2023-04-13 15:08:17,641	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_checkpoint' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\experiment_state-2023-04-13_09-14-14.json'
# 2023-04-13 15:08:22,717	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_checkpoint' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\experiment_state-2023-04-13_09-14-14.json'
# 2023-04-13 15:15:48,231	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:15:54,374	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:16:00,495	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:16:06,590	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:16:12,639	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:16:18,754	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:16:24,854	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:16:30,935	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:16:37,007	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:16:43,086	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:16:49,053	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:17:21,658	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:17:27,738	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:17:33,781	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:17:39,878	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:40:53,027	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:44:20,146	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:44:26,233	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:44:32,290	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:44:38,410	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:45:10,959	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:45:17,016	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:45:23,042	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:45:55,534	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:46:28,007	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:46:34,038	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:47:54,218	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:49:46,026	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:49:52,119	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:52:58,031	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:53:04,044	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:53:10,150	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:53:16,250	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:53:48,739	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:53:54,779	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:54:00,865	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:54:33,342	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:54:39,386	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:54:45,383	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:54:51,438	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:55:23,949	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:55:30,024	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:56:02,569	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:57:49,386	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_search_generator_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\search_gen_state-2023-04-13_09-14-14.json'
# 2023-04-13 15:57:55,422	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:58:01,572	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 15:59:44,262	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 16:00:16,758	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 16:00:44,114	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 16:03:39,758	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 16:03:45,834	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 16:04:39,989	WARNING trial_runner.py:964 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 16:06:38,180	WARNING tune.py:767 -- Trial Runner checkpointing failed: [WinError 5] Zugriff verweigert: 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\.tmp_searcher_ckpt' -> 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\ml_prediction\\ray_results\\xgboost_tuning\\searcher-state-2023-04-13_09-14-14.pkl'
# 2023-04-13 16:06:38,211	INFO tune.py:798 -- Total run time: 24743.80 seconds (24742.71 seconds for the tuning loop).
# Best hyperparameters found:
# {'learning_rate': 0.04441260710575024, 'max_depth': 3, 'n_estimators': 5753, 'subsample': 0.7740023907923075, 'colsample_bytree': 0.8444436871904553, 'colsample_bylevel': 0.9759004083903826, 'reg_alpha': 24.526677001061625, 'reg_lambda': 1.2740176072964426}
# Wall time: 6h 52min 27s

# %%
best_params = analysis.get_best_config(metric='rmse')
print("Best hyperparameters found:")
print(best_params)
# Out:
# Best hyperparameters found:
# {'learning_rate': 0.04441260710575024, 'max_depth': 3, 'n_estimators': 5753, 'subsample': 0.7740023907923075, 'colsample_bytree': 0.8444436871904553, 'colsample_bylevel': 0.9759004083903826, 'reg_alpha': 24.526677001061625, 'reg_lambda': 1.2740176072964426}
