# %% [markdown]
# # Featuer Engineering
#
# ## Part 1: Data Merging WITH preserving NaNs

# %%
# define root directory
import warnings
import re
import pandas as pd
import datetime


root_directory = 'C:\\Users/manue\\switchdrive\\Mutual Funds Project\\data\\predictors\\raw'

# %%
import glob
sub_directories = glob.glob("C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\data\\predictors\\raw\\*")
sub_directories[1]

# %%
# get path to each file in each subdirectory
filepath = []
from os import walk
for folder in sub_directories:
    files = next(walk(folder), (None, None, []))[2]  # [] if no file
    for file in files:
        filepath.append(folder + '\\' + file)

# %%
import calendar

# get all monthly dates
years = range(1980,2023,1)
months = range(1,13,1)

last_day_of_month = []
for year in years:
    for month in months:
        first, last = calendar.monthrange(year, month)
        last_day_of_month.append(datetime.datetime(year, month, last).date())

# %% [raw]
# # Manually need to adjust return data as date there is always the first of the NEXT month
# # harmonize with other data where it is always to the last of the month
#
# returns = pd.read_csv("C:/Users/manue/switchdrive/Mutual Funds Project/data/predictors/raw/Returns/returns.csv", index_col = 'SecId')
#
# #adjust date to one day before:
# dates = [datetime.datetime.strptime(date, '%Y-%m-%d').date() for date in list(returns.columns)]
# dates
#
# from datetime import timedelta
# adjusted_ret_dates = [date- timedelta(days=1) for date in dates]
#
# returns.columns = adjusted_ret_dates
# returns.to_csv('C:/Users/manue/switchdrive/Mutual Funds Project/data/predictors/raw/Returns/returns.csv')

# %%
#funds_IDs = pd.read_excel('C:/Users/manue/switchdrive/Mutual Funds Project/data/investment_list.xlsx')

warnings.filterwarnings('ignore')

regex = re.compile('(?s:.*){}(.*){}'.format(re.escape('\\'), re.escape('.csv')))

funds_IDs = list(pd.read_excel('C:/Users/manue/switchdrive/Mutual Funds Project/data/investment_list.xlsx')[0])

for date in last_day_of_month:
    print(date)
    string_date_format1 = date.strftime('%d/%m/%Y')
    string_date_format2 = date.strftime('%Y-%m-%d')
    monthly_df = pd.DataFrame(index= funds_IDs)
    for file in filepath:
        print(file)
        var_name = regex.findall(file)[0]
        
        variable_file = pd.read_csv(file, index_col = 'SecId')
        variable_file = variable_file.loc[variable_file.index.dropna()] #drop rows with no Fund ID
        variable_file = variable_file[~variable_file.index.duplicated(keep='first')] #drop duplicate entries
        if len(variable_file.columns) > 50: #we ignore data that are only available on a yearly basis
            try:
                variable_file = pd.DataFrame(variable_file.loc[:,string_date_format1])
                variable_file.rename(columns={string_date_format1: var_name}, inplace = True)
                monthly_df = pd.concat([monthly_df, variable_file], axis=1)

            except KeyError:
                variable_file = pd.DataFrame(variable_file.loc[:,string_date_format2])
                variable_file.rename(columns={string_date_format2: var_name}, inplace = True)
                monthly_df = pd.concat([monthly_df, variable_file], axis=1)
    monthly_df.dropna(how='all', inplace = True)

    monthly_df.to_csv('C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\data\\features_new\\' + string_date_format2 + ".csv", header=True, index=True,)

# %% [markdown]
# ## Part 2: Merging all months to single dataset

# %%
from os import walk
import pandas as pd

datasets_path = 'C:\\Users\\manue\\switchdrive\\Mutual Funds Project\\data\\features_new\\'
single_datasets = next(walk(datasets_path), (None, None, []))[2] 
#all_CSVs = [pd.read_csv(datasets_path+str(file)) for file in single_datasets]

# %%
for file in single_datasets:
    print(file)
    df = pd.read_csv(datasets_path+str(file))
    df.dropna(subset=['returns'], inplace = True) # drop all rows where we do not have a return
    df.replace(',','', regex=True, inplace=True)
    df = df.apply(pd.to_numeric, errors='ignore')
    df.to_csv(datasets_path+str(file))

# %%
subset1 = single_datasets[0:300]
subset2 = single_datasets[300:380]
subset3 = single_datasets[380:450]
subset4 = single_datasets[450:]

# %%
all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# Out:
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (312) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (312) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (312) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (312) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (312) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (312) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (312) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (312) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (312) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (312) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (261,262,268) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (261,262,268) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (261,262,268) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (261,262,268) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (261,262,268) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (261) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (261,262) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]
# C:\Users\manue\AppData\Local\Temp\ipykernel_13168\3445341391.py:1: DtypeWarning: Columns (261,262) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_CSVs_subset1 = [pd.read_csv(datasets_path+str(file)) for file in subset1]

# %%
df_sub1 = pd.concat(all_CSVs_subset1)

# %%
df_sub1 = df_sub1.iloc[:,1:]
df_sub1
# Out:
#        Unnamed: 0  #_Stock_Holdings_Long  #_Stock_Holdings_Short  \
# 0      FOUSA00BH9                    NaN                     NaN
# 1      F0GBR06HWW                    NaN                     NaN
# 2      FOUSA00FQB                    NaN                     NaN
# 3      F0GBR04DD8                    NaN                     NaN
# 4      FOUSA00C6V                    NaN                     NaN
# ...           ...                    ...                     ...
# 10647  F0GBR04RXA                  343.0                     NaN
# 10648  F0GBR04L29                   42.0                     NaN
# 10649  F0GBR053DN                    NaN                     NaN
# 10650  F0GBR04QTD                   47.0                     NaN
# 10651  F0GBR06B7N                    NaN                     NaN
#
#        %_Asset_In_Top_10_Holdings  Eq_Market_Value  Total_Market_Value_Long  \
# 0                             NaN              NaN                      NaN
# 1                             NaN              NaN                      NaN
# 2                             NaN              NaN                      NaN
# 3                             NaN              NaN                      NaN
# 4                             NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 10647                        8.73      192678096.0             3.768356e+08
# 10648                       36.73      975030491.0             2.000143e+08
# 10649                         NaN              NaN                      NaN
# 10650                       32.32       19262212.0             2.645156e+07
# 10651                         NaN              NaN                      NaN
#
#        Total_Market_Value_Net  Total_Market_Value_Short  Cash_%_Net  \
# 0                         NaN                       NaN         NaN
# 1                         NaN                       NaN         NaN
# 2                         NaN                       NaN         NaN
# 3                         NaN                       NaN         NaN
# 4                         NaN                       NaN         NaN
# ...                       ...                       ...         ...
# 10647            3.768356e+08                       NaN         NaN
# 10648            2.000143e+08                       NaN        0.38
# 10649                     NaN                       NaN         NaN
# 10650            2.645156e+07                       NaN         NaN
# 10651                     NaN                       NaN         NaN
#
#        Estimated_FundLevel_Net_Flow_Monthly_Comprehensive  ...  \
# 0                                                    NaN   ...
# 1                                                    NaN   ...
# 2                                                    NaN   ...
# 3                                                    NaN   ...
# 4                                                    NaN   ...
# ...                                                  ...   ...
# 10647                                         -911341.84   ...
# 10648                                           47460.93   ...
# 10649                                                NaN   ...
# 10650                                        -3111062.70   ...
# 10651                                                NaN   ...
#
#        Eq_Type_Distressed_Net  Eq_Type_HardAsset_Net  Eq_Type_HighYield_Net  \
# 0                         NaN                    NaN                    NaN
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 10647                     NaN                    NaN                    NaN
# 10648                     NaN                    NaN                    NaN
# 10649                     NaN                    NaN                    NaN
# 10650                    1.48                   5.98                   4.55
# 10651                     NaN                    NaN                    NaN
#
#        Eq_Type_Other_Net  Eq_Type_Slow_Growth_Net  \
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
# ...                  ...                      ...
# 10647                NaN                      NaN
# 10648                NaN                      NaN
# 10649                NaN                      NaN
# 10650               2.31                    21.43
# 10651                NaN                      NaN
#
#        Eq_Type_Speculative_Growth_Net  Rating  \
# 0                                 NaN     NaN
# 1                                 NaN     NaN
# 2                                 NaN     NaN
# 3                                 NaN     NaN
# 4                                 NaN     NaN
# ...                               ...     ...
# 10647                             NaN     4.0
# 10648                             NaN     4.0
# 10649                             NaN     NaN
# 10650                            4.78     3.0
# 10651                             NaN     NaN
#
#        Active_Share_ETF_Benchmark_Proxy  returns  \
# 0                                   NaN   0.0569
# 1                                   NaN   0.6882
# 2                                   NaN   0.1295
# 3                                   NaN   0.1186
# 4                                   NaN   0.1214
# ...                                 ...      ...
# 10647                               NaN   0.0471
# 10648                             82.84   0.0473
# 10649                               NaN   0.0310
# 10650                               NaN   0.0346
# 10651                               NaN   0.0326
#
#        Portfolio_Corporate_Sustainability_Score
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 10647                                       NaN
# 10648                                       NaN
# 10649                                       NaN
# 10650                                       NaN
# 10651                                       NaN
#
# [1075749 rows x 353 columns]

# %%
nan_ratio = [sum(df_sub1.iloc[:,row].isna())/len(df_sub1.iloc[:,row]) for row in range(0,len(df_sub1.columns))]

# %%
nan_ratio

# %%
df_sub1
# Out:
#        Unnamed: 0  #_Stock_Holdings_Long  #_Stock_Holdings_Short  \
# 0      FOUSA00BH9                    NaN                     NaN
# 1      F0GBR06HWW                    NaN                     NaN
# 2      FOUSA00FQB                    NaN                     NaN
# 3      F0GBR04DD8                    NaN                     NaN
# 4      FOUSA00C6V                    NaN                     NaN
# ...           ...                    ...                     ...
# 10647  F0GBR04RXA                  343.0                     NaN
# 10648  F0GBR04L29                   42.0                     NaN
# 10649  F0GBR053DN                    NaN                     NaN
# 10650  F0GBR04QTD                   47.0                     NaN
# 10651  F0GBR06B7N                    NaN                     NaN
#
#        %_Asset_In_Top_10_Holdings  Eq_Market_Value  Total_Market_Value_Long  \
# 0                             NaN              NaN                      NaN
# 1                             NaN              NaN                      NaN
# 2                             NaN              NaN                      NaN
# 3                             NaN              NaN                      NaN
# 4                             NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 10647                        8.73      192678096.0             3.768356e+08
# 10648                       36.73      975030491.0             2.000143e+08
# 10649                         NaN              NaN                      NaN
# 10650                       32.32       19262212.0             2.645156e+07
# 10651                         NaN              NaN                      NaN
#
#        Total_Market_Value_Net  Total_Market_Value_Short  Cash_%_Net  \
# 0                         NaN                       NaN         NaN
# 1                         NaN                       NaN         NaN
# 2                         NaN                       NaN         NaN
# 3                         NaN                       NaN         NaN
# 4                         NaN                       NaN         NaN
# ...                       ...                       ...         ...
# 10647            3.768356e+08                       NaN         NaN
# 10648            2.000143e+08                       NaN        0.38
# 10649                     NaN                       NaN         NaN
# 10650            2.645156e+07                       NaN         NaN
# 10651                     NaN                       NaN         NaN
#
#        Estimated_FundLevel_Net_Flow_Monthly_Comprehensive  ...  \
# 0                                                    NaN   ...
# 1                                                    NaN   ...
# 2                                                    NaN   ...
# 3                                                    NaN   ...
# 4                                                    NaN   ...
# ...                                                  ...   ...
# 10647                                         -911341.84   ...
# 10648                                           47460.93   ...
# 10649                                                NaN   ...
# 10650                                        -3111062.70   ...
# 10651                                                NaN   ...
#
#        Eq_Type_Distressed_Net  Eq_Type_HardAsset_Net  Eq_Type_HighYield_Net  \
# 0                         NaN                    NaN                    NaN
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 10647                     NaN                    NaN                    NaN
# 10648                     NaN                    NaN                    NaN
# 10649                     NaN                    NaN                    NaN
# 10650                    1.48                   5.98                   4.55
# 10651                     NaN                    NaN                    NaN
#
#        Eq_Type_Other_Net  Eq_Type_Slow_Growth_Net  \
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
# ...                  ...                      ...
# 10647                NaN                      NaN
# 10648                NaN                      NaN
# 10649                NaN                      NaN
# 10650               2.31                    21.43
# 10651                NaN                      NaN
#
#        Eq_Type_Speculative_Growth_Net  Rating  \
# 0                                 NaN     NaN
# 1                                 NaN     NaN
# 2                                 NaN     NaN
# 3                                 NaN     NaN
# 4                                 NaN     NaN
# ...                               ...     ...
# 10647                             NaN     4.0
# 10648                             NaN     4.0
# 10649                             NaN     NaN
# 10650                            4.78     3.0
# 10651                             NaN     NaN
#
#        Active_Share_ETF_Benchmark_Proxy  returns  \
# 0                                   NaN   0.0569
# 1                                   NaN   0.6882
# 2                                   NaN   0.1295
# 3                                   NaN   0.1186
# 4                                   NaN   0.1214
# ...                                 ...      ...
# 10647                               NaN   0.0471
# 10648                             82.84   0.0473
# 10649                               NaN   0.0310
# 10650                               NaN   0.0346
# 10651                               NaN   0.0326
#
#        Portfolio_Corporate_Sustainability_Score
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 10647                                       NaN
# 10648                                       NaN
# 10649                                       NaN
# 10650                                       NaN
# 10651                                       NaN
#
# [1075749 rows x 353 columns]

# %%
df_sub1.drop(columns=['Unnamed: 0'], inplace = True) # fund name is not needed in analysis

# %%
list(df_sub1.select_dtypes(include=['object']).columns)
# Out:
# ['Financial_Health_Grade_Long',
#  'Growth_Grade_Long',
#  'Profitability_Grade_Long',
#  'Eq_Stylebox_Long']

# %%
df_sub1
# Out:
#        #_Stock_Holdings_Long  #_Stock_Holdings_Short  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 10647                  343.0                     NaN
# 10648                   42.0                     NaN
# 10649                    NaN                     NaN
# 10650                   47.0                     NaN
# 10651                    NaN                     NaN
#
#        %_Asset_In_Top_10_Holdings  Eq_Market_Value  Total_Market_Value_Long  \
# 0                             NaN              NaN                      NaN
# 1                             NaN              NaN                      NaN
# 2                             NaN              NaN                      NaN
# 3                             NaN              NaN                      NaN
# 4                             NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 10647                        8.73      192678096.0             3.768356e+08
# 10648                       36.73      975030491.0             2.000143e+08
# 10649                         NaN              NaN                      NaN
# 10650                       32.32       19262212.0             2.645156e+07
# 10651                         NaN              NaN                      NaN
#
#        Total_Market_Value_Net  Total_Market_Value_Short  Cash_%_Net  \
# 0                         NaN                       NaN         NaN
# 1                         NaN                       NaN         NaN
# 2                         NaN                       NaN         NaN
# 3                         NaN                       NaN         NaN
# 4                         NaN                       NaN         NaN
# ...                       ...                       ...         ...
# 10647            3.768356e+08                       NaN         NaN
# 10648            2.000143e+08                       NaN        0.38
# 10649                     NaN                       NaN         NaN
# 10650            2.645156e+07                       NaN         NaN
# 10651                     NaN                       NaN         NaN
#
#        Estimated_FundLevel_Net_Flow_Monthly_Comprehensive  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10647                                         -911341.84
# 10648                                           47460.93
# 10649                                                NaN
# 10650                                        -3111062.70
# 10651                                                NaN
#
#        Fund_Size_Monthly_Comprehensive  ...  Eq_Type_Distressed_Net  \
# 0                                  NaN  ...                     NaN
# 1                                  NaN  ...                     NaN
# 2                                  NaN  ...                     NaN
# 3                                  NaN  ...                     NaN
# 4                                  NaN  ...                     NaN
# ...                                ...  ...                     ...
# 10647                     3.763007e+08  ...                     NaN
# 10648                     2.003609e+08  ...                     NaN
# 10649                              NaN  ...                     NaN
# 10650                     2.645156e+07  ...                    1.48
# 10651                              NaN  ...                     NaN
#
#        Eq_Type_HardAsset_Net  Eq_Type_HighYield_Net  Eq_Type_Other_Net  \
# 0                        NaN                    NaN                NaN
# 1                        NaN                    NaN                NaN
# 2                        NaN                    NaN                NaN
# 3                        NaN                    NaN                NaN
# 4                        NaN                    NaN                NaN
# ...                      ...                    ...                ...
# 10647                    NaN                    NaN                NaN
# 10648                    NaN                    NaN                NaN
# 10649                    NaN                    NaN                NaN
# 10650                   5.98                   4.55               2.31
# 10651                    NaN                    NaN                NaN
#
#        Eq_Type_Slow_Growth_Net  Eq_Type_Speculative_Growth_Net  Rating  \
# 0                          NaN                             NaN     NaN
# 1                          NaN                             NaN     NaN
# 2                          NaN                             NaN     NaN
# 3                          NaN                             NaN     NaN
# 4                          NaN                             NaN     NaN
# ...                        ...                             ...     ...
# 10647                      NaN                             NaN     4.0
# 10648                      NaN                             NaN     4.0
# 10649                      NaN                             NaN     NaN
# 10650                    21.43                            4.78     3.0
# 10651                      NaN                             NaN     NaN
#
#        Active_Share_ETF_Benchmark_Proxy  returns  \
# 0                                   NaN   0.0569
# 1                                   NaN   0.6882
# 2                                   NaN   0.1295
# 3                                   NaN   0.1186
# 4                                   NaN   0.1214
# ...                                 ...      ...
# 10647                               NaN   0.0471
# 10648                             82.84   0.0473
# 10649                               NaN   0.0310
# 10650                               NaN   0.0346
# 10651                               NaN   0.0326
#
#        Portfolio_Corporate_Sustainability_Score
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 10647                                       NaN
# 10648                                       NaN
# 10649                                       NaN
# 10650                                       NaN
# 10651                                       NaN
#
# [1075749 rows x 352 columns]

# %%
test = pd.concat([
        df_sub1.select_dtypes([], ['float64']),
        df_sub1.select_dtypes(['float64']).apply(pd.Series.astype, dtype='float32')
        ], axis=1)

test = pd.concat([
        test.select_dtypes([], ['object']),
        test.select_dtypes(['object']).apply(pd.Series.astype, dtype='category')
        ], axis=1)

# %%
df_sub1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1075749 entries, 0 to 10651
# Columns: 352 entries, #_Stock_Holdings_Long to Portfolio_Corporate_Sustainability_Score
# dtypes: float64(348), object(4)
# memory usage: 2.8+ GB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1075749 entries, 0 to 10651
# Columns: 352 entries, #_Stock_Holdings_Long to Eq_Stylebox_Long
# dtypes: category(4), float32(348)
# memory usage: 1.4 GB

# %%
df_sub1
# Out:
#        #_Stock_Holdings_Long  #_Stock_Holdings_Short  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 10647                  343.0                     NaN
# 10648                   42.0                     NaN
# 10649                    NaN                     NaN
# 10650                   47.0                     NaN
# 10651                    NaN                     NaN
#
#        %_Asset_In_Top_10_Holdings  Eq_Market_Value  Total_Market_Value_Long  \
# 0                             NaN              NaN                      NaN
# 1                             NaN              NaN                      NaN
# 2                             NaN              NaN                      NaN
# 3                             NaN              NaN                      NaN
# 4                             NaN              NaN                      NaN
# ...                           ...              ...                      ...
# 10647                        8.73      192678096.0             3.768356e+08
# 10648                       36.73      975030491.0             2.000143e+08
# 10649                         NaN              NaN                      NaN
# 10650                       32.32       19262212.0             2.645156e+07
# 10651                         NaN              NaN                      NaN
#
#        Total_Market_Value_Net  Total_Market_Value_Short  Cash_%_Net  \
# 0                         NaN                       NaN         NaN
# 1                         NaN                       NaN         NaN
# 2                         NaN                       NaN         NaN
# 3                         NaN                       NaN         NaN
# 4                         NaN                       NaN         NaN
# ...                       ...                       ...         ...
# 10647            3.768356e+08                       NaN         NaN
# 10648            2.000143e+08                       NaN        0.38
# 10649                     NaN                       NaN         NaN
# 10650            2.645156e+07                       NaN         NaN
# 10651                     NaN                       NaN         NaN
#
#        Estimated_FundLevel_Net_Flow_Monthly_Comprehensive  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10647                                         -911341.84
# 10648                                           47460.93
# 10649                                                NaN
# 10650                                        -3111062.70
# 10651                                                NaN
#
#        Fund_Size_Monthly_Comprehensive  ...  Eq_Type_Distressed_Net  \
# 0                                  NaN  ...                     NaN
# 1                                  NaN  ...                     NaN
# 2                                  NaN  ...                     NaN
# 3                                  NaN  ...                     NaN
# 4                                  NaN  ...                     NaN
# ...                                ...  ...                     ...
# 10647                     3.763007e+08  ...                     NaN
# 10648                     2.003609e+08  ...                     NaN
# 10649                              NaN  ...                     NaN
# 10650                     2.645156e+07  ...                    1.48
# 10651                              NaN  ...                     NaN
#
#        Eq_Type_HardAsset_Net  Eq_Type_HighYield_Net  Eq_Type_Other_Net  \
# 0                        NaN                    NaN                NaN
# 1                        NaN                    NaN                NaN
# 2                        NaN                    NaN                NaN
# 3                        NaN                    NaN                NaN
# 4                        NaN                    NaN                NaN
# ...                      ...                    ...                ...
# 10647                    NaN                    NaN                NaN
# 10648                    NaN                    NaN                NaN
# 10649                    NaN                    NaN                NaN
# 10650                   5.98                   4.55               2.31
# 10651                    NaN                    NaN                NaN
#
#        Eq_Type_Slow_Growth_Net  Eq_Type_Speculative_Growth_Net  Rating  \
# 0                          NaN                             NaN     NaN
# 1                          NaN                             NaN     NaN
# 2                          NaN                             NaN     NaN
# 3                          NaN                             NaN     NaN
# 4                          NaN                             NaN     NaN
# ...                        ...                             ...     ...
# 10647                      NaN                             NaN     4.0
# 10648                      NaN                             NaN     4.0
# 10649                      NaN                             NaN     NaN
# 10650                    21.43                            4.78     3.0
# 10651                      NaN                             NaN     NaN
#
#        Active_Share_ETF_Benchmark_Proxy  returns  \
# 0                                   NaN   0.0569
# 1                                   NaN   0.6882
# 2                                   NaN   0.1295
# 3                                   NaN   0.1186
# 4                                   NaN   0.1214
# ...                                 ...      ...
# 10647                               NaN   0.0471
# 10648                             82.84   0.0473
# 10649                               NaN   0.0310
# 10650                               NaN   0.0346
# 10651                               NaN   0.0326
#
#        Portfolio_Corporate_Sustainability_Score
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 10647                                       NaN
# 10648                                       NaN
# 10649                                       NaN
# 10650                                       NaN
# 10651                                       NaN
#
# [1075749 rows x 352 columns]
